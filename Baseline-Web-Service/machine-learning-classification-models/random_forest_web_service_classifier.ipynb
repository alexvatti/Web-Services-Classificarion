# %% [markdown]
# # Web Service Classification using Random Forest

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import class_weight
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

def train_and_report_random_forest(X_train, X_test, y_train, y_test, name="Model"):
    classes = np.unique(y_train)
    weights = class_weight.compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights_dict = dict(zip(classes, weights))

    # Train model with class weights
    model = RandomForestClassifier(n_estimators=200, class_weight=class_weights_dict, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(f"\n{name} Classification Report:\n")
    print(classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred, labels=np.unique(y_test))
    print("\nConfusion Matrix:\n")

    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
                xticklabels=np.unique(y_test), 
                yticklabels=np.unique(y_test))
    plt.title(f"Confusion Matrix: {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    for n in [10,20,30,40,50]:
        tfidf_df = pd.read_csv(f"../feature-extraction/Pre_Processed_Top_{n}_Web_Services_Categories_TFIDF.csv")
        sbert_df = pd.read_csv(f"../feature-extraction/Pre_Processed_Top_{n}_Web_Services_Categories_SBERT_Embeddings.csv")
        original_df = pd.read_csv(f"../data-preprocessing/Pre_Processed_Top_{n}_Web_Services_Categories.csv")
        labels = original_df['Service Classification'].fillna("Unknown")

        combined_df = pd.concat([tfidf_df, sbert_df], axis=1)

        X_train, X_test, y_train, y_test = train_test_split(combined_df, labels, test_size=0.2, random_state=42)
        X_train_tfidf, X_test_tfidf, y_train, y_test = train_test_split(tfidf_df, labels, test_size=0.2, random_state=42)
        X_train_sbert, X_test_sbert, y_train, y_test = train_test_split(sbert_df, labels, test_size=0.2, random_state=42)


        train_and_report_random_forest(X_train_tfidf, X_test_tfidf, y_train, y_test, name=f"TF-IDF with Top {n} Web Services")
        train_and_report_random_forest(X_train_sbert, X_test_sbert, y_train, y_test, name=f"SBERT with Top {n} Web Services")
        train_and_report_random_forest(X_train, X_test, y_train, y_test, name=f"TFIDF + SBERT with Top {n} Web Services")
# Out:
# TF-IDF with Top 10 Web Services Classification Report:
#
#               precision    recall  f1-score   support
#
#   Enterprise       0.59      0.36      0.44        67
#    Financial       0.87      0.74      0.80       130
#   Government       0.86      0.82      0.84        72
#      Mapping       0.87      0.82      0.84        72
#    Messaging       0.80      0.91      0.85        78
#     Payments       0.81      0.89      0.85       100
#       Social       0.72      0.77      0.75        99
#    Telephony       0.82      0.63      0.71        49
#        Tools       0.56      0.78      0.65       156
#    eCommerce       0.91      0.73      0.81       118
#
#     accuracy                           0.76       941
#    macro avg       0.78      0.74      0.75       941
# weighted avg       0.77      0.76      0.76       941
#
#
# Confusion Matrix:
# SBERT with Top 10 Web Services Classification Report:
#
#               precision    recall  f1-score   support
#
#   Enterprise       0.53      0.27      0.36        67
#    Financial       0.65      0.80      0.72       130
#   Government       0.85      0.61      0.71        72
#      Mapping       0.85      0.85      0.85        72
#    Messaging       0.72      0.74      0.73        78
#     Payments       0.75      0.80      0.78       100
#       Social       0.79      0.77      0.78        99
#    Telephony       0.90      0.57      0.70        49
#        Tools       0.55      0.78      0.64       156
#    eCommerce       0.92      0.69      0.79       118
#
#     accuracy                           0.71       941
#    macro avg       0.75      0.69      0.71       941
# weighted avg       0.73      0.71      0.71       941
#
#
# Confusion Matrix:
# TFIDF + SBERT with Top 10 Web Services Classification Report:
#
#               precision    recall  f1-score   support
#
#   Enterprise       0.52      0.24      0.33        67
#    Financial       0.71      0.76      0.74       130
#   Government       0.87      0.67      0.76        72
#      Mapping       0.88      0.92      0.90        72
#    Messaging       0.83      0.83      0.83        78
#     Payments       0.77      0.86      0.82       100
#       Social       0.78      0.75      0.76        99
#    Telephony       0.85      0.57      0.68        49
#        Tools       0.55      0.84      0.67       156
#    eCommerce       0.93      0.69      0.79       118
#
#     accuracy                           0.74       941
#    macro avg       0.77      0.71      0.73       941
# weighted avg       0.76      0.74      0.73       941
#
#
# Confusion Matrix:
# TF-IDF with Top 20 Web Services Classification Report:
#
#                 precision    recall  f1-score   support
#
#    Advertising       0.65      0.56      0.60        43
#          Email       0.80      0.73      0.76        51
#     Enterprise       0.62      0.49      0.55        72
#      Financial       0.82      0.70      0.75       152
#     Government       0.67      0.57      0.62        63
#        Mapping       0.77      0.82      0.80        74
#      Messaging       0.80      0.89      0.84       116
#       Payments       0.67      0.84      0.75        76
#      Reference       0.44      0.09      0.15        46
#        Science       0.69      0.69      0.69        45
#         Search       0.54      0.47      0.50        57
#       Security       0.64      0.50      0.56        54
#         Social       0.70      0.68      0.69        91
#         Sports       0.98      0.74      0.84        57
#      Telephony       0.63      0.63      0.63        51
#          Tools       0.44      0.72      0.55       159
# Transportation       0.77      0.67      0.71        45
#         Travel       0.75      0.80      0.77        54
#          Video       0.75      0.83      0.79        36
#      eCommerce       0.77      0.70      0.73        93
#
#       accuracy                           0.68      1435
#      macro avg       0.70      0.66      0.66      1435
#   weighted avg       0.69      0.68      0.67      1435
#
#
# Confusion Matrix:
# SBERT with Top 20 Web Services Classification Report:
#
#                 precision    recall  f1-score   support
#
#    Advertising       0.86      0.44      0.58        43
#          Email       0.86      0.75      0.80        51
#     Enterprise       0.57      0.32      0.41        72
#      Financial       0.63      0.77      0.69       152
#     Government       0.65      0.57      0.61        63
#        Mapping       0.66      0.85      0.75        74
#      Messaging       0.75      0.77      0.76       116
#       Payments       0.67      0.87      0.76        76
#      Reference       0.57      0.09      0.15        46
#        Science       0.72      0.80      0.76        45
#         Search       0.80      0.35      0.49        57
#       Security       0.78      0.54      0.64        54
#         Social       0.77      0.68      0.72        91
#         Sports       0.98      0.77      0.86        57
#      Telephony       0.68      0.53      0.59        51
#          Tools       0.43      0.77      0.55       159
# Transportation       0.79      0.69      0.74        45
#         Travel       0.86      0.70      0.78        54
#          Video       0.77      0.83      0.80        36
#      eCommerce       0.79      0.70      0.74        93
#
#       accuracy                           0.67      1435
#      macro avg       0.73      0.64      0.66      1435
#   weighted avg       0.70      0.67      0.66      1435
#
#
# Confusion Matrix:
# TFIDF + SBERT with Top 20 Web Services Classification Report:
#
#                 precision    recall  f1-score   support
#
#    Advertising       0.79      0.53      0.64        43
#          Email       0.91      0.78      0.84        51
#     Enterprise       0.50      0.21      0.29        72
#      Financial       0.72      0.75      0.73       152
#     Government       0.75      0.60      0.67        63
#        Mapping       0.70      0.86      0.78        74
#      Messaging       0.79      0.89      0.83       116
#       Payments       0.69      0.86      0.76        76
#      Reference       0.57      0.09      0.15        46
#        Science       0.71      0.71      0.71        45
#         Search       0.79      0.39      0.52        57
#       Security       0.79      0.50      0.61        54
#         Social       0.75      0.68      0.71        91
#         Sports       0.98      0.79      0.87        57
#      Telephony       0.73      0.63      0.67        51
#          Tools       0.43      0.82      0.57       159
# Transportation       0.83      0.67      0.74        45
#         Travel       0.80      0.80      0.80        54
#          Video       0.85      0.92      0.88        36
#      eCommerce       0.80      0.77      0.79        93
#
#       accuracy                           0.69      1435
#      macro avg       0.74      0.66      0.68      1435
#   weighted avg       0.72      0.69      0.68      1435
#
#
# Confusion Matrix:
# TF-IDF with Top 30 Web Services Classification Report:
#
#                     precision    recall  f1-score   support
#
#        Advertising       0.70      0.57      0.63        49
#            Bitcoin       0.75      0.62      0.68        24
#              Cloud       0.53      0.72      0.61        32
#               Data       0.91      0.37      0.53        27
#           Database       0.40      0.26      0.32        23
#          Education       0.74      0.73      0.74        44
#              Email       0.74      0.82      0.78        45
#         Enterprise       0.45      0.28      0.35        89
#          Financial       0.73      0.58      0.64       137
#              Games       0.79      0.83      0.81        46
#         Government       0.73      0.63      0.68        70
#            Mapping       0.60      0.77      0.67        77
#          Messaging       0.74      0.92      0.82       110
#              Music       0.76      0.78      0.77        37
#              Other       0.00      0.00      0.00        33
#           Payments       0.66      0.84      0.74        81
#             Photos       0.68      0.87      0.76        31
# Project Management       0.53      0.82      0.65        28
#          Reference       0.89      0.15      0.25        55
#            Science       0.70      0.57      0.62        69
#             Search       0.61      0.55      0.58        49
#           Security       0.76      0.43      0.55        58
#             Social       0.65      0.64      0.65        86
#             Sports       0.90      0.63      0.74        41
#          Telephony       0.77      0.54      0.64        68
#              Tools       0.27      0.59      0.37       137
#     Transportation       0.69      0.65      0.67        34
#             Travel       0.62      0.70      0.66        57
#              Video       0.82      0.84      0.83        38
#          eCommerce       0.77      0.68      0.72        98
#
#           accuracy                           0.62      1773
#          macro avg       0.66      0.61      0.62      1773
#       weighted avg       0.66      0.62      0.62      1773
#
#
# Confusion Matrix:
# SBERT with Top 30 Web Services Classification Report:
#
#                     precision    recall  f1-score   support
#
#        Advertising       1.00      0.39      0.56        49
#            Bitcoin       1.00      0.33      0.50        24
#              Cloud       0.55      0.56      0.55        32
#               Data       0.90      0.33      0.49        27
#           Database       1.00      0.09      0.16        23
#          Education       0.75      0.55      0.63        44
#              Email       0.82      0.82      0.82        45
#         Enterprise       0.68      0.24      0.35        89
#          Financial       0.47      0.75      0.58       137
#              Games       0.89      0.70      0.78        46
#         Government       0.70      0.60      0.65        70
#            Mapping       0.59      0.83      0.69        77
#          Messaging       0.66      0.83      0.73       110
#              Music       0.91      0.84      0.87        37
#              Other       0.00      0.00      0.00        33
#           Payments       0.64      0.84      0.73        81
#             Photos       0.80      0.65      0.71        31
# Project Management       0.74      0.50      0.60        28
#          Reference       0.54      0.13      0.21        55
#            Science       0.68      0.72      0.70        69
#             Search       0.75      0.43      0.55        49
#           Security       0.81      0.43      0.56        58
#             Social       0.70      0.62      0.65        86
#             Sports       0.91      0.78      0.84        41
#          Telephony       0.78      0.41      0.54        68
#              Tools       0.29      0.72      0.41       137
#     Transportation       0.68      0.50      0.58        34
#             Travel       0.84      0.74      0.79        57
#              Video       0.73      1.00      0.84        38
#          eCommerce       0.67      0.60      0.63        98
#
#           accuracy                           0.61      1773
#          macro avg       0.72      0.56      0.59      1773
#       weighted avg       0.67      0.61      0.60      1773
#
#
# Confusion Matrix:
# TFIDF + SBERT with Top 30 Web Services Classification Report:
#
#                     precision    recall  f1-score   support
#
#        Advertising       0.91      0.59      0.72        49
#            Bitcoin       0.85      0.46      0.59        24
#              Cloud       0.58      0.66      0.62        32
#               Data       0.90      0.33      0.49        27
#           Database       0.57      0.17      0.27        23
#          Education       0.76      0.57      0.65        44
#              Email       0.75      0.89      0.82        45
#         Enterprise       0.61      0.21      0.32        89
#          Financial       0.57      0.77      0.66       137
#              Games       0.93      0.83      0.87        46
#         Government       0.81      0.63      0.71        70
#            Mapping       0.59      0.84      0.69        77
#          Messaging       0.76      0.91      0.83       110
#              Music       0.94      0.86      0.90        37
#              Other       0.00      0.00      0.00        33
#           Payments       0.64      0.81      0.72        81
#             Photos       0.84      0.68      0.75        31
# Project Management       0.71      0.61      0.65        28
#          Reference       0.67      0.11      0.19        55
#            Science       0.80      0.62      0.70        69
#             Search       0.68      0.47      0.55        49
#           Security       0.82      0.40      0.53        58
#             Social       0.69      0.65      0.67        86
#             Sports       0.91      0.73      0.81        41
#          Telephony       0.84      0.53      0.65        68
#              Tools       0.28      0.72      0.40       137
#     Transportation       0.83      0.59      0.69        34
#             Travel       0.79      0.74      0.76        57
#              Video       0.77      0.97      0.86        38
#          eCommerce       0.76      0.67      0.71        98
#
#           accuracy                           0.64      1773
#          macro avg       0.72      0.60      0.63      1773
#       weighted avg       0.69      0.64      0.63      1773
#
#
# Confusion Matrix:
# TF-IDF with Top 40 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.58      0.67      0.62        42
#               Analytics       0.37      0.41      0.39        17
# Application Development       0.00      0.00      0.00        25
#                 Backend       0.42      0.24      0.30        21
#                 Banking       0.87      0.59      0.70        34
#                 Bitcoin       0.81      0.75      0.78        28
#                   Cloud       0.50      0.62      0.55        34
#                    Data       0.71      0.21      0.32        24
#                Database       0.62      0.37      0.47        27
#               Education       0.70      0.74      0.72        38
#                   Email       0.79      0.79      0.79        43
#              Enterprise       0.42      0.36      0.39        75
#                  Events       0.65      0.83      0.73        24
#               Financial       0.63      0.69      0.66       122
#                   Games       0.62      0.74      0.67        39
#              Government       0.61      0.59      0.60        59
#      Internet of Things       0.72      0.56      0.63        32
#                 Mapping       0.65      0.79      0.71        70
#                 Medical       0.48      0.63      0.55        19
#               Messaging       0.80      0.92      0.86       113
#                   Music       0.77      0.87      0.82        39
#                   Other       0.33      0.04      0.06        28
#                Payments       0.75      0.80      0.78        97
#                  Photos       0.69      0.76      0.72        45
#      Project Management       0.53      0.73      0.62        22
#               Reference       0.25      0.05      0.08        43
#                 Science       0.64      0.57      0.61        63
#                  Search       0.56      0.57      0.56        60
#                Security       0.74      0.45      0.56        51
#                Shipping       0.72      0.84      0.78        25
#                  Social       0.66      0.57      0.61        90
#                  Sports       0.91      0.73      0.81        41
#                  Stocks       0.97      0.94      0.95        31
#               Telephony       0.69      0.57      0.62        61
#                   Tools       0.33      0.59      0.42       160
#          Transportation       0.71      0.59      0.65        51
#                  Travel       0.73      0.74      0.73        54
#                   Video       0.74      0.80      0.77        54
#                 Weather       0.70      0.78      0.74        27
#               eCommerce       0.71      0.50      0.59        88
#
#                accuracy                           0.62      2016
#               macro avg       0.63      0.60      0.60      2016
#            weighted avg       0.63      0.62      0.61      2016
#
#
# Confusion Matrix:
# SBERT with Top 40 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.88      0.52      0.66        42
#               Analytics       1.00      0.06      0.11        17
# Application Development       0.57      0.16      0.25        25
#                 Backend       0.50      0.14      0.22        21
#                 Banking       1.00      0.32      0.49        34
#                 Bitcoin       0.70      0.25      0.37        28
#                   Cloud       0.45      0.50      0.47        34
#                    Data       0.67      0.17      0.27        24
#                Database       1.00      0.15      0.26        27
#               Education       0.75      0.39      0.52        38
#                   Email       0.82      0.86      0.84        43
#              Enterprise       0.37      0.27      0.31        75
#                  Events       0.93      0.54      0.68        24
#               Financial       0.34      0.74      0.46       122
#                   Games       0.77      0.59      0.67        39
#              Government       0.60      0.54      0.57        59
#      Internet of Things       1.00      0.12      0.22        32
#                 Mapping       0.58      0.87      0.70        70
#                 Medical       0.69      0.58      0.63        19
#               Messaging       0.73      0.79      0.76       113
#                   Music       0.92      0.87      0.89        39
#                   Other       0.00      0.00      0.00        28
#                Payments       0.69      0.79      0.74        97
#                  Photos       0.80      0.62      0.70        45
#      Project Management       0.81      0.59      0.68        22
#               Reference       0.29      0.09      0.14        43
#                 Science       0.65      0.63      0.64        63
#                  Search       0.51      0.32      0.39        60
#                Security       0.88      0.43      0.58        51
#                Shipping       0.89      0.68      0.77        25
#                  Social       0.60      0.58      0.59        90
#                  Sports       0.84      0.76      0.79        41
#                  Stocks       0.90      0.58      0.71        31
#               Telephony       0.76      0.57      0.65        61
#                   Tools       0.29      0.68      0.41       160
#          Transportation       0.74      0.61      0.67        51
#                  Travel       0.82      0.69      0.75        54
#                   Video       0.77      0.81      0.79        54
#                 Weather       0.85      0.81      0.83        27
#               eCommerce       0.63      0.64      0.63        88
#
#                accuracy                           0.57      2016
#               macro avg       0.70      0.51      0.55      2016
#            weighted avg       0.64      0.57      0.57      2016
#
#
# Confusion Matrix:
# TFIDF + SBERT with Top 40 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.68      0.62      0.65        42
#               Analytics       1.00      0.35      0.52        17
# Application Development       0.80      0.16      0.27        25
#                 Backend       0.64      0.33      0.44        21
#                 Banking       0.92      0.32      0.48        34
#                 Bitcoin       0.75      0.54      0.62        28
#                   Cloud       0.50      0.62      0.55        34
#                    Data       0.71      0.21      0.32        24
#                Database       0.67      0.15      0.24        27
#               Education       0.85      0.61      0.71        38
#                   Email       0.79      0.86      0.82        43
#              Enterprise       0.44      0.31      0.36        75
#                  Events       0.83      0.83      0.83        24
#               Financial       0.46      0.75      0.57       122
#                   Games       0.76      0.67      0.71        39
#              Government       0.67      0.59      0.63        59
#      Internet of Things       0.88      0.44      0.58        32
#                 Mapping       0.65      0.87      0.74        70
#                 Medical       0.56      0.74      0.64        19
#               Messaging       0.76      0.91      0.83       113
#                   Music       0.87      0.87      0.87        39
#                   Other       0.00      0.00      0.00        28
#                Payments       0.76      0.86      0.81        97
#                  Photos       0.87      0.60      0.71        45
#      Project Management       0.67      0.73      0.70        22
#               Reference       0.33      0.05      0.08        43
#                 Science       0.68      0.62      0.65        63
#                  Search       0.54      0.48      0.51        60
#                Security       0.85      0.43      0.57        51
#                Shipping       0.88      0.88      0.88        25
#                  Social       0.65      0.61      0.63        90
#                  Sports       0.82      0.80      0.81        41
#                  Stocks       1.00      0.94      0.97        31
#               Telephony       0.77      0.54      0.63        61
#                   Tools       0.32      0.68      0.44       160
#          Transportation       0.74      0.61      0.67        51
#                  Travel       0.84      0.80      0.82        54
#                   Video       0.76      0.81      0.79        54
#                 Weather       0.73      0.81      0.77        27
#               eCommerce       0.67      0.61      0.64        88
#
#                accuracy                           0.63      2016
#               macro avg       0.70      0.59      0.61      2016
#            weighted avg       0.66      0.63      0.62      2016
#
#
# Confusion Matrix:
# TF-IDF with Top 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.56      0.64      0.60        42
#               Analytics       0.40      0.30      0.34        20
# Application Development       0.09      0.05      0.06        20
#                 Backend       0.64      0.26      0.37        27
#                 Banking       0.73      0.46      0.56        24
#                 Bitcoin       0.79      0.83      0.81        23
#                    Chat       0.59      0.62      0.61        16
#                   Cloud       0.53      0.64      0.58        36
#                    Data       0.58      0.27      0.37        26
#                Database       0.33      0.21      0.26        28
#                 Domains       0.86      0.95      0.90        20
#               Education       0.64      0.80      0.71        35
#                   Email       0.78      0.73      0.75        52
#              Enterprise       0.48      0.25      0.33        85
#           Entertainment       0.41      0.37      0.39        19
#                  Events       0.62      0.91      0.74        22
#            File Sharing       0.61      0.73      0.67        15
#               Financial       0.69      0.69      0.69       117
#                   Games       0.86      0.83      0.84        52
#              Government       0.68      0.67      0.67        60
#                  Images       0.12      0.08      0.10        13
#      Internet of Things       0.54      0.59      0.57        22
#                 Mapping       0.64      0.78      0.71        78
#                   Media       1.00      0.31      0.48        16
#                 Medical       0.64      0.67      0.65        21
#               Messaging       0.77      0.87      0.82       129
#                   Music       0.81      0.86      0.84        44
#           News Services       0.54      0.50      0.52        14
#                  Office       0.00      0.00      0.00        15
#                   Other       0.00      0.00      0.00        30
#                Payments       0.71      0.79      0.75        99
#                  Photos       0.58      0.70      0.63        47
#      Project Management       0.51      0.67      0.58        30
#             Real Estate       0.74      0.87      0.80        30
#               Reference       0.80      0.08      0.14        52
#                 Science       0.78      0.65      0.71        60
#                  Search       0.39      0.47      0.43        47
#                Security       0.53      0.41      0.46        39
#                Shipping       0.60      0.84      0.70        25
#                  Social       0.49      0.61      0.55        79
#                  Sports       0.95      0.69      0.80        52
#                  Stocks       0.85      0.96      0.90        24
#                 Storage       0.52      0.55      0.54        20
#               Telephony       0.59      0.61      0.60        57
#                   Tools       0.29      0.50      0.37       151
#          Transportation       0.80      0.70      0.74        46
#                  Travel       0.75      0.84      0.79        45
#                   Video       0.74      0.83      0.78        48
#                 Weather       0.83      0.89      0.86        28
#               eCommerce       0.67      0.51      0.58        92
#
#                accuracy                           0.61      2192
#               macro avg       0.60      0.58      0.57      2192
#            weighted avg       0.62      0.61      0.60      2192
#
#
# Confusion Matrix:
# SBERT with Top 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.77      0.40      0.53        42
#               Analytics       1.00      0.05      0.10        20
# Application Development       0.50      0.20      0.29        20
#                 Backend       0.80      0.15      0.25        27
#                 Banking       0.90      0.38      0.53        24
#                 Bitcoin       0.80      0.17      0.29        23
#                    Chat       0.60      0.38      0.46        16
#                   Cloud       0.65      0.78      0.71        36
#                    Data       0.67      0.23      0.34        26
#                Database       0.75      0.11      0.19        28
#                 Domains       0.93      0.70      0.80        20
#               Education       0.67      0.51      0.58        35
#                   Email       0.80      0.83      0.81        52
#              Enterprise       0.33      0.22      0.27        85
#           Entertainment       1.00      0.16      0.27        19
#                  Events       0.76      0.59      0.67        22
#            File Sharing       0.77      0.67      0.71        15
#               Financial       0.38      0.79      0.51       117
#                   Games       0.89      0.75      0.81        52
#              Government       0.62      0.57      0.59        60
#                  Images       0.33      0.08      0.12        13
#      Internet of Things       1.00      0.14      0.24        22
#                 Mapping       0.60      0.87      0.71        78
#                   Media       1.00      0.06      0.12        16
#                 Medical       0.70      0.67      0.68        21
#               Messaging       0.59      0.74      0.66       129
#                   Music       0.78      0.98      0.87        44
#           News Services       1.00      0.36      0.53        14
#                  Office       0.00      0.00      0.00        15
#                   Other       0.00      0.00      0.00        30
#                Payments       0.70      0.87      0.78        99
#                  Photos       0.71      0.57      0.64        47
#      Project Management       0.50      0.27      0.35        30
#             Real Estate       1.00      0.13      0.24        30
#               Reference       0.40      0.04      0.07        52
#                 Science       0.78      0.67      0.72        60
#                  Search       0.50      0.38      0.43        47
#                Security       0.57      0.31      0.40        39
#                Shipping       0.86      0.76      0.81        25
#                  Social       0.50      0.63      0.56        79
#                  Sports       0.94      0.88      0.91        52
#                  Stocks       0.90      0.79      0.84        24
#                 Storage       0.80      0.20      0.32        20
#               Telephony       0.67      0.53      0.59        57
#                   Tools       0.24      0.59      0.34       151
#          Transportation       0.77      0.59      0.67        46
#                  Travel       0.80      0.82      0.81        45
#                   Video       0.62      0.94      0.75        48
#                 Weather       0.87      0.93      0.90        28
#               eCommerce       0.61      0.64      0.63        92
#
#                accuracy                           0.57      2192
#               macro avg       0.69      0.48      0.51      2192
#            weighted avg       0.63      0.57      0.55      2192
#
#
# Confusion Matrix:
# TFIDF + SBERT with Top 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.64      0.64      0.64        42
#               Analytics       0.40      0.10      0.16        20
# Application Development       1.00      0.20      0.33        20
#                 Backend       0.80      0.15      0.25        27
#                 Banking       0.90      0.38      0.53        24
#                 Bitcoin       0.80      0.52      0.63        23
#                    Chat       0.71      0.62      0.67        16
#                   Cloud       0.59      0.72      0.65        36
#                    Data       0.80      0.31      0.44        26
#                Database       0.75      0.11      0.19        28
#                 Domains       0.90      0.90      0.90        20
#               Education       0.64      0.66      0.65        35
#                   Email       0.83      0.85      0.84        52
#              Enterprise       0.46      0.21      0.29        85
#           Entertainment       0.67      0.21      0.32        19
#                  Events       0.61      0.86      0.72        22
#            File Sharing       0.77      0.67      0.71        15
#               Financial       0.52      0.79      0.63       117
#                   Games       0.88      0.81      0.84        52
#              Government       0.73      0.63      0.68        60
#                  Images       0.33      0.15      0.21        13
#      Internet of Things       0.71      0.55      0.62        22
#                 Mapping       0.66      0.88      0.76        78
#                   Media       0.00      0.00      0.00        16
#                 Medical       0.71      0.71      0.71        21
#               Messaging       0.77      0.91      0.84       129
#                   Music       0.81      0.95      0.88        44
#           News Services       0.62      0.36      0.45        14
#                  Office       0.00      0.00      0.00        15
#                   Other       0.00      0.00      0.00        30
#                Payments       0.75      0.85      0.80        99
#                  Photos       0.79      0.70      0.74        47
#      Project Management       0.55      0.60      0.57        30
#             Real Estate       0.86      0.83      0.85        30
#               Reference       0.67      0.08      0.14        52
#                 Science       0.84      0.70      0.76        60
#                  Search       0.47      0.40      0.44        47
#                Security       0.68      0.38      0.49        39
#                Shipping       0.78      0.84      0.81        25
#                  Social       0.60      0.71      0.65        79
#                  Sports       0.93      0.83      0.88        52
#                  Stocks       0.88      0.92      0.90        24
#                 Storage       0.73      0.40      0.52        20
#               Telephony       0.71      0.61      0.66        57
#                   Tools       0.27      0.60      0.37       151
#          Transportation       0.84      0.70      0.76        46
#                  Travel       0.76      0.91      0.83        45
#                   Video       0.70      0.92      0.79        48
#                 Weather       0.81      0.89      0.85        28
#               eCommerce       0.62      0.61      0.61        92
#
#                accuracy                           0.63      2192
#               macro avg       0.66      0.57      0.58      2192
#            weighted avg       0.66      0.63      0.61      2192
#
#
# Confusion Matrix:
